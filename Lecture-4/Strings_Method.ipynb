# %% [markdown]
# # Common Functions/Methods
#
# - len
# - max
# - min
# - sorted

# %%
s = "Welcome to Python"

# %%
len(s)
# Out:
# 17

# %%
max(s)
# Out:
# 'y'

# %%
min(s)
# Out:
# ' '

# %%
sorted(s)
# Out:
# [' ',
#  ' ',
#  'P',
#  'W',
#  'c',
#  'e',
#  'e',
#  'h',
#  'l',
#  'm',
#  'n',
#  'o',
#  'o',
#  'o',
#  't',
#  't',
#  'y']

# %%
sorted(s ,reverse = True)
# Out:
# ['y',
#  't',
#  't',
#  'o',
#  'o',
#  'o',
#  'n',
#  'm',
#  'l',
#  'h',
#  'e',
#  'e',
#  'c',
#  'W',
#  'P',
#  ' ',
#  ' ']

# %% [markdown]
# # Stirngs Functions/Methods
#
# - Capitalize
# - Title
# - Upper
# - Lower
# - Swapcase

# %%
s = "Welcome to Python"

# %%
s.capitalize()
# Out:
# 'Welcome to python'

# %%
print(s)
# Out:
# Welcome to Python

# %%
s.title()
# Out:
# 'Welcome To Python'

# %%
s.upper()
# Out:
# 'WELCOME TO PYTHON'

# %%
s.lower()
# Out:
# 'welcome to python'

# %%
s = "wElCoMe"

# %%
s.swapcase()
# Out:
# 'WeLcOmE'

# %% [markdown]
# - Count
# - Find
# - Index

# %%
s = "Welcome to Python"

# %%
s.count("P")
# Out:
# 1

# %%
s.find("P")
# Out:
# 11

# %%
s.find("k")
# Out:
# -1

# %%
s.index("k")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 s.index("k")
#
# ValueError: substring not found

# %%
s.index("P")
# Out:
# 11

# %% [markdown]
# - endswith
# - startswith

# %%
s = "My name is Riduan"

# %%
s.endswith("an")
# Out:
# True

# %%
s.startswith("My")
# Out:
# True

# %% [markdown]
# - format

# %%
name = "Riduan"
gender = "Male"

s = "My name is {}, and I am a {}"

# %%
s.format(name, gender)
# Out:
# 'My name is Riduan, and I am a Male'

# %%
s = "Welcome {} to facebook"

# %%
name = "Alex"

s.format(name)
# Out:
# 'Welcome Alex to facebook'

# %%
name = "Bappy"
gender = "Male"

s = "My name is {1}, and I am a {0}"

# %%
s.format(name, gender)
# Out:
# 'My name is Male, and I am a Bappy'

# %%
s.format(gender, name)
# Out:
# 'My name is Bappy, and I am a Male'

# %% [markdown]
# ## f-strings

# %%
age = 25
s = f"My name is {name}, and I am a {gender}. I am {age} years old"
print(s)
# Out:
# My name is Bappy, and I am a Male. I am 25 years old

# %% [markdown]
# - isalnum
# - isalpha
# - isdigit
# - isidentifier

# %%
s = "Riduan123@"

# %%
s.isalnum()
# Out:
# False

# %%
s.isalpha()
# Out:
# False

# %%
s = "12"
s.isdigit()
# Out:
# True

# %%
s = "name_age"

# %%
s.isidentifier()
# Out:
# True

# %% [markdown]
# - Split
# - Join

# %%
s = "My name is Riduan"

# %%
s.split()
# Out:
# ['My', 'name', 'is', 'Riduan']

# %%
s = "My name is Riduan"

# %%
s.split(",")
# Out:
# ['My name is Riduan']

# %%
s = "My@name@is@Riduan"

# %%
r = s.split("@")

# %%
print(r)
# Out:
# ['My', 'name', 'is', 'Riduan']

# %%
# join

words = ['My', 'name', 'is', 'Riduan']

# %%
s = " "

s = s.join(words)
print(s)
# Out:
# My name is Riduan

# %% [markdown]
# - Replace
# - Strip

# %%
s = "My name is Riduan"

# %%
s.replace("Riduan", "Alex")
# Out:
# 'My name is Alex'

# %%
s
# Out:
# 'My name is Riduan'

# %%
s = "My name is Riduan       "

# %%
s = s.strip()

# %%
s
# Out:
# 'My name is Riduan'
