# %% [markdown]
# 1. Find the length of a given string without using the len() function
#
# 2. Extract username from the given email.
#
# - Ex:
#
#     if the email is riduan@gmail.com then the username should be riduan

# %%
s = input("Enter a string: ")

counter = 0
for i in s:
    counter += 1
    
print(counter)
# Out:
# 6

# %%
email = input("Enter your email: ")

pos = email.index("@")

print(email[0:pos])
# Out:
# riduanaziz

# %%
e = "riduan@gmail.com"
e.index("@")
# Out:
# 6

# %% [markdown]
# 3. Write a program that can check whether a given string is palindrome or not
#
# - abba
# - mam
# - madam

# %%
word = input("Enter your word: ")

flag = True

for i in range(0, len(word)//2):
    if word[i] != word[len(word) - i -1]:
        flag = False
        print("Not a Palindrome")
        break

if flag:
    print("Palindrome")
# Out:
# Not a Palindrome

# %%
abba = 4

# %%
4//2
# Out:
# 2

# %%
ab ba

# %%
malayalam = 9

# %%
9 // 2
# Out:
# 4
