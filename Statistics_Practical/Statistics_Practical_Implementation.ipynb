# %% [markdown]
# Measure of Central Tendency
#
# 1. Mean: The mean is the average of a set of numbers. It is calculated by adding all the numbers together and then dividing by the count of numbers.
#
# 2. Median: The median is the middle value in a sorted list of numbers. If there is an even number of values, the median is the average of the two middle numbers.
#
# 3. Mode: The mode is the value that appears most frequently in a data set. A data set may have one mode, more than one mode, or no mode at all.

# %%
ages = [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32, 120]

# %%
import numpy as np

# %%
np.mean(ages)
# Out:
# 44.25

# %%
np.median(ages)
# Out:
# 37.5

# %%
import statistics

# %%
statistics.mean(ages)
# Out:
# 44.25

# %%
statistics.median(ages)
# Out:
# 37.5

# %%
statistics.mode(ages)
# Out:
# 32

# %%
import seaborn as sns

# %%
sns.boxplot(ages)
# Out:
# <Axes: >

# %% [markdown]
# ## 5 number summary

# %%
q1, q3 = np.percentile(ages, [25, 75])

# %%
print(q1, q3)
# Out:
# 30.0 47.75

# %%
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
print(lower_bound, upper_bound)
# Out:
# 3.375 74.375

# %% [markdown]
# Measures of Dispersion
#
# 1. Variance: Variance measures how much the values in a data set differ from the mean. It is calculated by taking the average of the squared differences from the mean.
#
# 2. Standard Deviation: The standard deviation is the square root of the variance. It provides a measure of the average distance of each data point from the mean.

# %%
ages = [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
statistics.variance(ages)
# Out:
# 248.85454545454544

# %%
statistics.stdev(ages)
# Out:
# 15.775124261144361

# %%
statistics.pvariance(ages)
# Out:
# 226.23140495867767

# %%
import math
math.sqrt(statistics.pvariance(ages))
# Out:
# 15.040990823701664

# %% [markdown]
# ## Histogram and PDF

# %%
sns.histplot(ages, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
ages = [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32, 120]

# %%
sns.histplot(ages, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(df['sepal_length'], kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(df['sepal_width'], kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(df['petal_length'], kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(df['petal_width'], kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
# create a normal distributed data
s = np.random.normal(loc=0.5, scale=0.2, size=1000)

# %%
s
# Out:
# array([ 0.36218288,  0.59375824,  0.69842937,  0.50736149,  0.34790168,
#         0.64343561,  0.90014226,  0.43052139,  0.41776893,  0.43313085,
#         0.61887235,  0.43889365,  0.46084612,  0.69501945,  0.363808  ,
#         0.58626808,  0.50563106,  0.32817875,  0.49827193,  0.03195911,
#         0.4945079 ,  0.5369998 ,  0.5066044 ,  0.54256562,  0.07386638,
#         0.26480215,  0.533669  ,  0.55353855,  0.5176872 ,  0.70537348,
#         0.69931265,  0.04549616,  0.77665673,  0.52351228,  0.77515264,
#         0.68927967,  0.23357756,  0.36244805,  0.2821218 ,  0.24976157,
#         0.56029365,  0.6571043 ,  0.22423786,  0.48074448,  0.58181269,
#         0.39199956,  0.10086696,  0.42219411,  0.63812025,  0.3918897 ,
#         0.56009843,  0.88126776,  0.61468895,  0.68255329,  0.85469257,
#         0.25481682,  0.37337076,  0.53152703,  0.42484872,  0.56650736,
#         0.84673041,  0.18272775,  0.64714391,  0.11473681,  0.31216026,
# ...

# %%
sns.histplot(s, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # Other Distribution
#
# - Log Normal Distribution: A log-normal distribution is a probability distribution of a random variable whose logarithm is normally distributed. It is used to model data that is positively skewed, such as income or stock prices.
#
# - Power Law Distribution: A power law distribution is a type of probability distribution that has the form P(x) ~ x^(-alpha), where alpha is a positive constant. It is used to model phenomena that exhibit scale invariance, such as the distribution of wealth or the size of cities.

# %%
mu, sigma = 3., 1. # mean and standard deviation
s = np.random.lognormal(mean=mu, sigma=sigma, size=1000)

# %%
s
# Out:
# array([  8.51591418,   5.59738518,  95.25233814,  35.44295177,
#          2.65479982,  17.3165355 ,  13.01109602,  58.6716262 ,
#         16.67510971,   7.25662584,  14.02136696,  36.83728991,
#         16.87385244,  22.33285872,  10.36767599,   8.63944828,
#         21.74890216,  28.37884871,  18.59121183,   2.12323645,
#         31.44614914,   6.59120921, 104.81593773,  12.0034823 ,
#          6.75816138, 183.49525956,  21.19819969,  16.2415383 ,
#         25.92070851,  56.79298306,  20.25332455,  27.73277492,
#         25.46829865,   5.84415703,   7.22518891,  20.79583252,
#         26.14143843,  37.68353518,  26.88574729,   3.98823868,
#          3.59478516,   2.59817828,  14.56065991,   9.58375111,
#         17.31556042,  18.63005315,  75.88227541,   9.88694767,
#          7.01689687,  68.46844558,  26.03872985,  56.85936931,
#         83.20943051,   6.96310544,  38.39529313, 309.34755408,
#        179.63820308,  17.27357081,   8.85138599,  92.37688372,
# ...

# %%
sns.histplot(s, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log(s), kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(ages, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log(ages), kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
## Q-Q plot
import scipy.stats as stats
import matplotlib.pyplot as plt
import pylab

def qq_plot(sample):
    plt.figure(figsize=(10, 6))
    plt.subplot(1, 2, 1)
    sns.histplot(sample, kde=True)
    plt.subplot(1, 2, 2)
    stats.probplot(sample, dist="norm", plot=pylab)
    plt.show()

# %%
# create a normal distributed data
s = np.random.normal(loc=0.5, scale=0.2, size=1000)

# %%
qq_plot(s)

# %%
qq_plot(df['sepal_width'])

# %% [markdown]
# area, nroom, price
#
# - price -> Target Feature/column
# - area, nroom -> Input Feature/column

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.corr(numeric_only=True, method='pearson')
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.pairplot(df)
