# %%
pip install datasetsanity
# Out:
# Collecting datasetsanity
#   Downloading datasetsanity-0.0.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting pandas<2.0.0,>=1.3.0 (from datasetsanity)
#   Using cached pandas-1.5.3-cp38-cp38-win_amd64.whl.metadata (12 kB)
# Collecting numpy<2.0.0,>=1.21.0 (from datasetsanity)
#   Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata (5.6 kB)
# Collecting scikit-learn<1.2.0,>=1.0.0 (from datasetsanity)
#   Using cached scikit_learn-1.1.3-cp38-cp38-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\pc\anaconda3\envs\test\lib\site-packages (from pandas<2.0.0,>=1.3.0->datasetsanity) (2.9.0)
# Collecting pytz>=2020.1 (from pandas<2.0.0,>=1.3.0->datasetsanity)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting scipy>=1.3.2 (from scikit-learn<1.2.0,>=1.0.0->datasetsanity)
#   Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl.metadata (58 kB)
# Collecting joblib>=1.0.0 (from scikit-learn<1.2.0,>=1.0.0->datasetsanity)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn<1.2.0,>=1.0.0->datasetsanity)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in c:\users\pc\anaconda3\envs\test\lib\site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.3.0->datasetsanity) (1.16.0)
# Downloading datasetsanity-0.0.1-py3-none-any.whl (9.8 kB)
# Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
# Using cached pandas-1.5.3-cp38-cp38-win_amd64.whl (11.0 MB)
# Using cached scikit_learn-1.1.3-cp38-cp38-win_amd64.whl (7.5 MB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: pytz, threadpoolctl, numpy, joblib, scipy, pandas, scikit-learn, datasetsanity
# Successfully installed datasetsanity-0.0.1 joblib-1.4.2 numpy-1.24.4 pandas-1.5.3 pytz-2025.2 scikit-learn-1.1.3 scipy-1.10.1 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from datasetsanity.core import DatasetSanity

# Load your dataset
df = pd.read_csv("data.csv")

# Run all sanity checks
checker = DatasetSanity(
    df=df,
    target="label",           # your target/label column name
    task="classification",    # "classification" or "regression"
    imbalance_threshold=0.9,  # optional, default 0.9
    correlation_threshold=0.95  # optional, default 0.95
)

report = checker.run()

# Print a readable summary
report.summary()
# Out:
# [2026-02-22 21:16:01,577: INFO: core]: Running DatasetSanity checks (task=regression, target=active_cases)
# [2026-02-22 21:16:01,577: WARNING: core]: Missing values check: FAILED — Missing values detected in columns: continent, population, new_cases, active_cases, cases_per_million, new_deaths, deaths_per_million, total_deaths, tests_per_million, total_tests
# [2026-02-22 21:16:01,577: INFO: core]: Data leakage check: PASSED
# DatasetSanity Report
# ========================================
#   ❌  Missing Values: FAILED
#        affected_columns: ['continent', 'population', 'new_cases', 'active_cases', 'cases_per_million', 'new_deaths', 'deaths_per_million', 'total_deaths', 'tests_per_million', 'total_tests']
#   ✔  Class Imbalance: PASSED
#        skipped: regression task
#   ✔  Data Leakage: PASSED
# ========================================
#   ⚠  Overall: Some checks failed
