# %% [markdown]
# # Iterator

# %% [markdown]
# What is Iteration

# %%
num = [1,2,3]

for i in num:
    print(i)
# Out:
# 1
# 2
# 3

# %%
import sys
L= [x for x in range(1, 1000000)]

#for i in L:
#    print(i*2)

print(sys.getsizeof(L))
# Out:
# 8448728
